# %%
import numpy as np
from scipy import stats
import pandas as pd

# %%
data = pd.read_csv('../data/model_training_data.csv')
data
# Out:
#       Sex   Age AgeClass  BodyweightKg WeightClassKg  Best3SquatKg  \
# 0       M  13.0    13-15         63.20            66         120.0
# 1       M  13.0    13-15         63.20            66         120.0
# 2       F  13.0    13-15         44.20            47          62.5
# 3       F  13.0    13-15         65.90            72         105.0
# 4       M  13.0    13-15         94.30           105         140.0
# ...    ..   ...      ...           ...           ...           ...
# 93451   M  85.0   80-999         80.60            83          65.0
# 93452   M  85.5   80-999         88.70            93          37.5
# 93453   F  90.0   80-999         71.34            72          20.0
# 93454   F  91.5   80-999         70.40            72          20.0
# 93455   F  92.0   80-999         69.90            72          20.0
#
#        Best3BenchKg  Best3DeadliftKg  TotalKg Country        Date
# 0              77.5            155.0    352.5     USA  2017-05-06
# ...

# %%
categorical = ['Sex', 'AgeClass', 'WeightClassKg']
quantitative = ['Age', 'BodyweightKg', 'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg', 'TotalKg']

# %%
count_m_y = len(data[(data['Sex'] == 'M') & (data['Age'] <= 30)])
count_m_o = len(data[(data['Sex'] == 'M') & (data['Age'] > 30)])
count_f_y = len(data[(data['Sex'] == 'F') & (data['Age'] <= 30)])
count_f_o = len(data[(data['Sex'] == 'F') & (data['Age'] > 30)])

# %%
pd.crosstab(data['Sex'], data['AgeClass'])
# Out:
# AgeClass  13-15  16-17  18-19  20-23  24-34  35-39  40-44  45-49  50-54  \
# Sex
# F           912   1881   2521   7139  12698   2585   2407   1689   1284
# M          1200   3891   6727  17265  20601   2504   2140   1606   1093
#
# AgeClass  55-59  60-64  65-69  70-74  75-79  80-999
# Sex
# F           663    398    234    100     27       7
# M           776    517    246    257     69      19

# %%
sex_vs_age = np.array([[count_m_y, count_m_o], [count_f_y, count_f_o]])
sex_vs_age
# Out:
# array([[44965, 13946],
#        [21370, 13175]])

# %%
# p_val is 0.0 < 0.05 so we reject the null hypothesis that sex and age group are independent
chi2, p_val, df, expected = stats.chi2_contingency(sex_vs_age)
p_val
expected
# Out:
# array([[41814.98443118, 17096.01556882],
#        [24520.01556882, 10024.98443118]])
