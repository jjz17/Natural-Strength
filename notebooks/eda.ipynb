# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/model_training_data.csv')
data
# Out:
#       Sex   Age AgeClass  BodyweightKg WeightClassKg  Best3SquatKg  \
# 0       M  13.0    13-15         63.20            66         120.0
# 1       M  13.0    13-15         63.20            66         120.0
# 2       F  13.0    13-15         44.20            47          62.5
# 3       F  13.0    13-15         65.90            72         105.0
# 4       M  13.0    13-15         94.30           105         140.0
# ...    ..   ...      ...           ...           ...           ...
# 93451   M  85.0   80-999         80.60            83          65.0
# 93452   M  85.5   80-999         88.70            93          37.5
# 93453   F  90.0   80-999         71.34            72          20.0
# 93454   F  91.5   80-999         70.40            72          20.0
# 93455   F  92.0   80-999         69.90            72          20.0
#
#        Best3BenchKg  Best3DeadliftKg  TotalKg Country        Date
# 0              77.5            155.0    352.5     USA  2017-05-06
# ...

# %%
plt.figure(figsize=(9,6))
sns.countplot(x='AgeClass', data=data)
# Most of the data is concentrated between the 18-19 and 35-39 age ranges
# Out:
# <AxesSubplot:xlabel='AgeClass', ylabel='count'>

# %%
sns.countplot(x='Sex', data=data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.histplot(data=data['TotalKg'])
# Out:
# <AxesSubplot:xlabel='TotalKg', ylabel='Count'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='BodyweightKg')
# Out:
# <AxesSubplot:xlabel='BodyweightKg', ylabel='Count'>

# %%
sns.displot(data=data, x='Age', y='TotalKg')

# %%
sns.relplot(data=data, x='Age', y='TotalKg', hue='Sex', col='Sex')

# %%
data.columns
# Out:
# Index(['Sex', 'Age', 'AgeClass', 'BodyweightKg', 'WeightClassKg',
#        'Best3SquatKg', 'Best3BenchKg', 'Best3DeadliftKg', 'TotalKg', 'Country',
#        'Date'],
#       dtype='object')

# %%
relevant_cols = ['Age', 'BodyweightKg', 'TotalKg']
sns.pairplot(data, vars = relevant_cols, hue = 'Sex', diag_kind = 'hist', 
             diag_kws = {'alpha':0.55, 'bins':20})

# %%
numeric_cols = data.select_dtypes('number').columns
numeric_cols
# Out:
# Index(['Age', 'BodyweightKg', 'Best3SquatKg', 'Best3BenchKg',
#        'Best3DeadliftKg', 'TotalKg'],
#       dtype='object')

# %%
sns.heatmap(data[numeric_cols].corr(), cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# with sns.axes_style('white'):
#     
# sns.jointplot('Age', 'TotalKg', data=data, kind='kde');
sns.jointplot(data=data, x='Age', y='TotalKg', kind='kde')

# %%
sns.jointplot(data=data, x='Age', y='TotalKg')

# %%
sns.factorplot('AgeClass', data=data, aspect=2, kind="count", color='steelblue')
# Out:
# /Users/jasonzhang/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /Users/jasonzhang/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
