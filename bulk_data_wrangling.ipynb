# %%
import os
import pandas as pd

# %%
df_chunk = []

# for chunk in pd.read_csv('online_retail_II.csv', encoding='ISO-8859-1', 
#                     parse_dates = ['InvoiceDate'], 
#                     chunksize = 1000):

for chunk in pd.read_csv(f'powerlifting_data{os.path.sep}powerlifting_data.csv', index_col=0, chunksize=10000):
#     df = chunk.dropna()
#     df['InvoiceDate'] = df['InvoiceDate'].dt.date
#     df.sort_values(by=['InvoiceDate'])
#     df.set_index('InvoiceDate', inplace=True)
#     df_chunk.append(df)
    df_chunk.append(chunk)

raw_df = pd.concat(df_chunk)

print(raw_df.info()) 

# data = pd.read_csv(f'powerlifting_data{os.path.sep}powerlifting_data.csv', index_col=0, chunksize=10000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2596986 entries, Alona Vladi to Hildeborg Juvet Hugdal
# Data columns (total 40 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Sex               object
#  1   Event             object
#  2   Equipment         object
#  3   Age               float64
#  4   AgeClass          object
#  5   BirthYearClass    object
#  6   Division          object
#  7   BodyweightKg      float64
#  8   WeightClassKg     object
#  9   Squat1Kg          float64
#  10  Squat2Kg          float64
#  11  Squat3Kg          float64
#  12  Squat4Kg          float64
#  13  Best3SquatKg      float64
#  14  Bench1Kg          float64
#  15  Bench2Kg          float64
#  16  Bench3Kg          float64
#  17  Bench4Kg          float64
#  18  Best3BenchKg      float64
#  19  Deadlift1Kg       float64
#  20  Deadlift2Kg       float64
#  21  Deadlift3Kg       float64
#  22  Deadlift4Kg       float64
#  23  Best3DeadliftKg   float64
# ...

# %%
raw_df.shape
# Out:
# (2596986, 40)

# %%
raw_df.head()
# Out:
#                        Sex Event Equipment   Age AgeClass BirthYearClass  \
# Name
# Alona Vladi              F   SBD       Raw  33.0    24-34          24-39
# Galina Solovyanova       F   SBD       Raw  43.0    40-44          40-49
# Daniil Voronin           M   SBD       Raw  15.5    16-17          14-18
# Aleksey Krasov           M   SBD       Raw  35.0    35-39          24-39
# Margarita Pleschenkova   M   SBD       Raw  26.5    24-34          24-39
#
#                        Division  BodyweightKg WeightClassKg  Squat1Kg  ...  \
# Name                                                                   ...
# Alona Vladi                   O         58.30            60      75.0  ...
# Galina Solovyanova           M1         73.10            75      95.0  ...
# Daniil Voronin                T         67.40            75      85.0  ...
# Aleksey Krasov                O         66.65            75     125.0  ...
# ...

# %%
raw_df['Event'].unique()
# Out:
# array(['SBD', 'SD', 'BD', 'D', 'B', 'S', 'SB'], dtype=object)

# %%
raw_df.columns
# Out:
# Index(['Sex', 'Event', 'Equipment', 'Age', 'AgeClass', 'BirthYearClass',
#        'Division', 'BodyweightKg', 'WeightClassKg', 'Squat1Kg', 'Squat2Kg',
#        'Squat3Kg', 'Squat4Kg', 'Best3SquatKg', 'Bench1Kg', 'Bench2Kg',
#        'Bench3Kg', 'Bench4Kg', 'Best3BenchKg', 'Deadlift1Kg', 'Deadlift2Kg',
#        'Deadlift3Kg', 'Deadlift4Kg', 'Best3DeadliftKg', 'TotalKg', 'Place',
#        'Dots', 'Wilks', 'Glossbrenner', 'Goodlift', 'Tested', 'Country',
#        'State', 'Federation', 'ParentFederation', 'Date', 'MeetCountry',
#        'MeetState', 'MeetTown', 'MeetName'],
#       dtype='object')

# %%
raw_df['Federation'].unique()
# Out:
# array(['GFP', 'CONBRAP', 'GPC', 'WUAP-AUT', 'WRPF', 'WRPF-KAZ',
#        'WPC-Iceland', 'WPC-Portugal', 'OceaniaPF', 'WP', 'OceaniaPO',
#        'GPC-CAN', 'WPAU', 'WPA', 'WPF', 'WPU', 'RAW-CAN', 'RAW',
#        'RAW-UKR', 'IDFPA', 'SVNL', 'NSF', 'FECHIPO', 'WPPL-Mexico',
#        'WRPF-CAN', 'IBSA', '365Strong', 'WUAP-RUS', 'WUAP', 'KDKS',
#        'KuwaitPL', 'SPF-IRL', 'XPC-Poland', 'FBPD', 'WPRO', 'NORCAL',
#        'GPF', 'ADFPF', 'USA-UA', 'IDFPF', 'SAPF', 'WPUF', 'BP', 'EPA',
#        'LGBT', 'NextGenPF', 'APC', 'GPA', 'DSF', 'WPPL-Belarus',
#        'WPC-RUS', 'WPC', 'GPC-RUS', 'WPC-Italy', 'CBLB', 'WPA-GEO',
#        'BVDG', 'NauruPF', 'IPC', 'NIPF', 'NZPF', 'KNKF-SP', 'BPU',
#        'ACHIPO', 'XPC', 'SPA', 'OEVK', 'UPC-Germany', 'SAST', 'WUAP-SVK',
#        'CAST', 'XPS', 'Fedepotencia', 'ProRaw', 'Poland-UA', 'England-UA',
#        'SPSS', 'WPPL-Ukraine', 'USAPL', 'NAPF', 'UkrainePA', 'GPU',
#        'MHSPLA', 'WRPF-HUN', 'SPF', 'PLZS', 'PLH', 'LPF', 'LJTF', 'CPU',
# ...

# %%
usapl_df = raw_df[raw_df['Federation'] == 'USAPL']

# %%
usapl_df.to_csv('usapl_data.csv', index=False)
